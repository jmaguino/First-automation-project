# %%
import openpyxl
import os
import pandas as pd
from openpyxl import load_workbook
import numpy

# %%
daily_totals = pd.read_excel ('SALES LOG - XYZ COMPANY.xlsx')

# %%
main_total = pd.read_excel ('tabula-END OF DAY REPORT - XYZ COMPANY.xlsx', header=3)

# %%
main_total
# Out:
#      PO #  CUSTOMER ID  DATE OF SALERECEIPT #                    AMOUNT  \
# 0   81730          NaN                    NaN                       NaN
# 1   81730       126104  03/13/2020 0001492287                        40
# 2   81730       139729  03/12/2020 0001492286                        50
# 3   81730       415802  03/14/2020 0001492281                       100
# 4   81730      1018908  03/12/2020 0001492288                        20
# 5   81730      1065569  03/05/2020 0001492289                      1500
# 6     NaN          NaN                    NaN                      1710
# 7     NaN          NaN                    NaN                       NaN
# 8     NaN          NaN                    NaN                       NaN
# 9   81733       129188  03/13/2020 0001492256                       150
# 10  81733       141077  03/13/2020 0001492248                     25000
# 11  81733       149443  03/11/2020 0001492251                      2000
# 12  81733       163549  03/12/2020 0001492260                      1600
# 13  81733       302068  03/14/2020 0001492277                       200
# 14  81733       318123  03/11/2020 0001492255                       444
# 15  81733       413376  03/11/2020 0001492265                      3200
# 16  81733       413376  03/13/2020 0001492270                       200
# 17  81733       424431  03/10/2020 0001492249                      1000
# 18  81733       432540  03/10/2020 0001492264                      7900
# 19  81733       432540  03/20/2020 0001492295                       100
# 20  81733       810469  03/14/2020 0001492278                       800
# 21  81733       824824  03/09/2020 0001492247                     25000
# 22  81733       834696  03/11/2020 0001492261                      3200
# 23  81733       837873  03/10/2020 0001492250                     714.5
# 24  81733       867566  03/13/2020 0001492267                        20
# 25  81733       873349  03/10/2020 0001492268                      3200
# 26  81733       877756  03/10/2020 0001492252                      1000
# 27  81733       907172  03/09/2020 0001492272                    268750
# 28  81733       907172  03/09/2020 0001492274                    100000
# 29  81733       914864  03/11/2020 0001492254                      1000
# 30  81733       916980  03/11/2020 0001492266                      1200
# 31  81733       936797  03/10/2020 0001492253                    457.28
# 32  81733       976785  03/12/2020 0001492275                     10000
# 33  81733       976785  03/12/2020 0001492276                      1400
# 34  81733       993472  03/13/2020 0001492245                        35
# 35  81733      1001448  03/11/2020 0001492269                      1200
# 36  81733      1002032  03/14/2020 0001492257                      1200
# 37  81733      1025858  03/11/2020 0001492262                        40
# 38  81733      1035053  03/13/2020 0001492259                      1200
# 39  81733      1035701  03/10/2020 0001492263                      2400
# 40  81733      1035704  03/09/2020 0001492258                      1200
# 41  81733      1039113  03/11/2020 0001492271                       100
# 42  81733      1043815  03/10/2020 0001492246                       100
# 43  81733      1054901  03/13/2020 0001492273                        15
# 44    NaN          NaN                    NaN                    466026
# 45    NaN          NaN                    NaN                       NaN
# 46    NaN          NaN                    NaN                       NaN
# 47    NaN          NaN            XYZ COMPANY                       NaN
# 48    NaN          NaN      END OF DAY REPORT                       NaN
# 49    NaN          NaN    2020-03-20 00:00:00                       NaN
# 50   PO #  CUSTOMER ID  DATE OF SALERECEIPT #         AMOUNT  SPEEDTYPE
# 51  81736       164304  03/14/2020 0001492293             $50.00 G0400A
# 52  81736       164304  03/14/2020 0001492294             $50.00 G1802A
# 53  81736       820366  03/13/2020 0001492290             $45.00 G0400A
# 54  81736       828968  03/15/2020 0001492291             $50.00 G1385A
# 55  81736       134593  03/16/2020 0001492292            $250.00 G1651A
# 56    NaN          NaN                    NaN                       445
# 57    NaN          NaN                    NaN  GRAND TOTAL: $468,180.78
#
#    SPEED TYPE
# 0         NaN
# 1      G0401A
# 2      G0419A
# 3      G0598A
# 4      G3035A
# 5      G2477A
# 6         NaN
# 7         NaN
# 8         NaN
# 9       A0176
# 10      A0116
# 11      A0168
# 12      A8008
# 13      A0108
# 14      A8008
# 15      A8008
# 16      A8008
# 17      A0168
# 18      A8008
# 19      A8008
# 20      A0108
# 21      A0063
# 22      A8008
# 23      A0168
# 24      A0018
# 25      A8008
# 26      A0168
# 27      A5737
# 28      A8005
# 29      A0168
# 30      A8008
# 31      A0168
# 32      A0010
# 33      A0108
# 34      A0176
# 35      A8008
# 36      A8008
# 37      A8008
# 38      A8008
# 39      A8008
# 40      A8008
# 41      A8008
# 42      A0010
# 43      AWBBL
# 44        NaN
# 45        NaN
# 46        NaN
# 47        NaN
# 48        NaN
# 49        NaN
# 50        NaN
# 51        NaN
# 52        NaN
# 53        NaN
# 54        NaN
# 55        NaN
# 56        NaN
# 57        NaN

# %%
daily_totals
# Out:
#     SALES ID         DEPOSIT DATE TENDER TYPE SALES TYPE   PO # DATE OF SALE  \
# 0          1  2020-02-26 00:00:00          CK      Check  81551   2020-03-02
# 1          1  2020-02-27 00:00:00          CK      Check  81563   2020-03-02
# 2          1  2020-02-27 00:00:00          CK      Check  81564   2020-03-02
# 3          4  2020-02-27 00:00:00          CK      Check  81565   2020-03-02
# 4          4  2020-02-27 00:00:00          CK      Check  81566   2020-03-02
# ..       ...                  ...         ...        ...    ...          ...
# 168      NaN                  NaN         NaN        NaN    NaN   2020-03-20
# 169      NaN                  NaN         NaN        NaN    NaN   2020-03-20
# 170      NaN                  NaN         NaN        NaN    NaN   2020-03-20
# 171      NaN                  NaN         NaN        NaN    NaN   2020-03-20
# 172      NaN                  NaN         NaN        NaN    NaN   2020-03-20
#
#     TAX RCPT SPECIAL  SALE AMT TAX EXEMPT AMT  ... ATH CAP  ATH AC CU  \
# 0         19       1   1090.00            NaN  ...     NaN        NaN
# 1          5     NaN   6578.84           1300  ...     NaN        NaN
# 2          0       1    200.00            NaN  ...     NaN        NaN
# 3         10       0   1700.00            NaN  ...     NaN        NaN
# 4          8       0   3675.00            NaN  ...     NaN        NaN
# ..       ...     ...       ...            ...  ...     ...        ...
# 168      NaN     NaN       NaN            NaN  ...     NaN        NaN
# 169      NaN     NaN       NaN            NaN  ...     NaN        NaN
# 170      NaN     NaN       NaN            NaN  ...     NaN        NaN
# 171      NaN     NaN       NaN            NaN  ...     NaN        NaN
# 172      NaN     NaN       NaN            NaN  ...     NaN        NaN
#
#     ATH RESTRICTRED RESTRICTED PD  CURRENT USE PD  ATH CU PD  ATH CAP PD  \
# 0               NaN           NaN             NaN        NaN         NaN
# 1               NaN           NaN             NaN        NaN         NaN
# 2               NaN           NaN             NaN        NaN         NaN
# 3               NaN           NaN             NaN        NaN         NaN
# 4               NaN           NaN             NaN        NaN         NaN
# ..              ...           ...             ...        ...         ...
# 168             NaN           NaN             NaN        NaN         NaN
# 169             NaN           NaN             NaN        NaN         NaN
# 170             NaN           NaN             NaN        NaN         NaN
# 171             NaN           NaN             NaN        NaN         NaN
# 172             NaN           NaN             NaN        NaN         NaN
#
#      ATH CU PD.1 ATH RESTRICTED PD  ADJ
# 0            NaN               NaN  NaN
# 1            NaN               NaN  NaN
# 2            NaN               NaN  NaN
# 3            NaN               NaN  NaN
# 4            NaN               NaN  NaN
# ..           ...               ...  ...
# 168          NaN               NaN  NaN
# 169          NaN               NaN  NaN
# 170          NaN               NaN  NaN
# 171          NaN               NaN  NaN
# 172          NaN               NaN  NaN
#
# [173 rows x 25 columns]

# %%
# Get the grand total from sales log
daily_grand_total = daily_totals.loc[daily_totals['TOTAL '].str.contains('GRAND TOTAL', na=False, case=False), 'QUOTE AMT']

# %%
# Get the grand total from the end of day report
main_grand_total = main_total.loc[main_total['AMOUNT'].str.contains('GRAND TOTAL', na=False), 'AMOUNT'].str.split('$').str[1].str.replace(',', '').astype(float).values[0]

# %%
main_total
# Out:
#      PO #  CUSTOMER ID  DATE OF SALERECEIPT #                    AMOUNT  \
# 0   81730          NaN                    NaN                       NaN
# 1   81730       126104  03/13/2020 0001492287                        40
# 2   81730       139729  03/12/2020 0001492286                        50
# 3   81730       415802  03/14/2020 0001492281                       100
# 4   81730      1018908  03/12/2020 0001492288                        20
# 5   81730      1065569  03/05/2020 0001492289                      1500
# 6     NaN          NaN                    NaN                      1710
# 7     NaN          NaN                    NaN                       NaN
# 8     NaN          NaN                    NaN                       NaN
# 9   81733       129188  03/13/2020 0001492256                       150
# 10  81733       141077  03/13/2020 0001492248                     25000
# 11  81733       149443  03/11/2020 0001492251                      2000
# 12  81733       163549  03/12/2020 0001492260                      1600
# 13  81733       302068  03/14/2020 0001492277                       200
# 14  81733       318123  03/11/2020 0001492255                       444
# 15  81733       413376  03/11/2020 0001492265                      3200
# 16  81733       413376  03/13/2020 0001492270                       200
# 17  81733       424431  03/10/2020 0001492249                      1000
# 18  81733       432540  03/10/2020 0001492264                      7900
# 19  81733       432540  03/20/2020 0001492295                       100
# 20  81733       810469  03/14/2020 0001492278                       800
# 21  81733       824824  03/09/2020 0001492247                     25000
# 22  81733       834696  03/11/2020 0001492261                      3200
# 23  81733       837873  03/10/2020 0001492250                     714.5
# 24  81733       867566  03/13/2020 0001492267                        20
# 25  81733       873349  03/10/2020 0001492268                      3200
# 26  81733       877756  03/10/2020 0001492252                      1000
# 27  81733       907172  03/09/2020 0001492272                    268750
# 28  81733       907172  03/09/2020 0001492274                    100000
# 29  81733       914864  03/11/2020 0001492254                      1000
# 30  81733       916980  03/11/2020 0001492266                      1200
# 31  81733       936797  03/10/2020 0001492253                    457.28
# 32  81733       976785  03/12/2020 0001492275                     10000
# 33  81733       976785  03/12/2020 0001492276                      1400
# 34  81733       993472  03/13/2020 0001492245                        35
# 35  81733      1001448  03/11/2020 0001492269                      1200
# 36  81733      1002032  03/14/2020 0001492257                      1200
# 37  81733      1025858  03/11/2020 0001492262                        40
# 38  81733      1035053  03/13/2020 0001492259                      1200
# 39  81733      1035701  03/10/2020 0001492263                      2400
# 40  81733      1035704  03/09/2020 0001492258                      1200
# 41  81733      1039113  03/11/2020 0001492271                       100
# 42  81733      1043815  03/10/2020 0001492246                       100
# 43  81733      1054901  03/13/2020 0001492273                        15
# 44    NaN          NaN                    NaN                    466026
# 45    NaN          NaN                    NaN                       NaN
# 46    NaN          NaN                    NaN                       NaN
# 47    NaN          NaN            XYZ COMPANY                       NaN
# 48    NaN          NaN      END OF DAY REPORT                       NaN
# 49    NaN          NaN    2020-03-20 00:00:00                       NaN
# 50   PO #  CUSTOMER ID  DATE OF SALERECEIPT #         AMOUNT  SPEEDTYPE
# 51  81736       164304  03/14/2020 0001492293             $50.00 G0400A
# 52  81736       164304  03/14/2020 0001492294             $50.00 G1802A
# 53  81736       820366  03/13/2020 0001492290             $45.00 G0400A
# 54  81736       828968  03/15/2020 0001492291             $50.00 G1385A
# 55  81736       134593  03/16/2020 0001492292            $250.00 G1651A
# 56    NaN          NaN                    NaN                       445
# 57    NaN          NaN                    NaN  GRAND TOTAL: $468,180.78
#
#    SPEED TYPE
# 0         NaN
# 1      G0401A
# 2      G0419A
# 3      G0598A
# 4      G3035A
# 5      G2477A
# 6         NaN
# 7         NaN
# 8         NaN
# 9       A0176
# 10      A0116
# 11      A0168
# 12      A8008
# 13      A0108
# 14      A8008
# 15      A8008
# 16      A8008
# 17      A0168
# 18      A8008
# 19      A8008
# 20      A0108
# 21      A0063
# 22      A8008
# 23      A0168
# 24      A0018
# 25      A8008
# 26      A0168
# 27      A5737
# 28      A8005
# 29      A0168
# 30      A8008
# 31      A0168
# 32      A0010
# 33      A0108
# 34      A0176
# 35      A8008
# 36      A8008
# 37      A8008
# 38      A8008
# 39      A8008
# 40      A8008
# 41      A8008
# 42      A0010
# 43      AWBBL
# 44        NaN
# 45        NaN
# 46        NaN
# 47        NaN
# 48        NaN
# 49        NaN
# 50        NaN
# 51        NaN
# 52        NaN
# 53        NaN
# 54        NaN
# 55        NaN
# 56        NaN
# 57        NaN

# %%
# They happen to be equal for your example
daily_grand_total == main_grand_total
# Out:
# 161    True
# Name: QUOTE AMT, dtype: bool

# %%
main_total
# Out:
#      PO #  CUSTOMER ID  DATE OF SALERECEIPT #                    AMOUNT  \
# 0   81730          NaN                    NaN                       NaN
# 1   81730       126104  03/13/2020 0001492287                        40
# 2   81730       139729  03/12/2020 0001492286                        50
# 3   81730       415802  03/14/2020 0001492281                       100
# 4   81730      1018908  03/12/2020 0001492288                        20
# 5   81730      1065569  03/05/2020 0001492289                      1500
# 6     NaN          NaN                    NaN                      1710
# 7     NaN          NaN                    NaN                       NaN
# 8     NaN          NaN                    NaN                       NaN
# 9   81733       129188  03/13/2020 0001492256                       150
# 10  81733       141077  03/13/2020 0001492248                     25000
# 11  81733       149443  03/11/2020 0001492251                      2000
# 12  81733       163549  03/12/2020 0001492260                      1600
# 13  81733       302068  03/14/2020 0001492277                       200
# 14  81733       318123  03/11/2020 0001492255                       444
# 15  81733       413376  03/11/2020 0001492265                      3200
# 16  81733       413376  03/13/2020 0001492270                       200
# 17  81733       424431  03/10/2020 0001492249                      1000
# 18  81733       432540  03/10/2020 0001492264                      7900
# 19  81733       432540  03/20/2020 0001492295                       100
# 20  81733       810469  03/14/2020 0001492278                       800
# 21  81733       824824  03/09/2020 0001492247                     25000
# 22  81733       834696  03/11/2020 0001492261                      3200
# 23  81733       837873  03/10/2020 0001492250                     714.5
# 24  81733       867566  03/13/2020 0001492267                        20
# 25  81733       873349  03/10/2020 0001492268                      3200
# 26  81733       877756  03/10/2020 0001492252                      1000
# 27  81733       907172  03/09/2020 0001492272                    268750
# 28  81733       907172  03/09/2020 0001492274                    100000
# 29  81733       914864  03/11/2020 0001492254                      1000
# 30  81733       916980  03/11/2020 0001492266                      1200
# 31  81733       936797  03/10/2020 0001492253                    457.28
# 32  81733       976785  03/12/2020 0001492275                     10000
# 33  81733       976785  03/12/2020 0001492276                      1400
# 34  81733       993472  03/13/2020 0001492245                        35
# 35  81733      1001448  03/11/2020 0001492269                      1200
# 36  81733      1002032  03/14/2020 0001492257                      1200
# 37  81733      1025858  03/11/2020 0001492262                        40
# 38  81733      1035053  03/13/2020 0001492259                      1200
# 39  81733      1035701  03/10/2020 0001492263                      2400
# 40  81733      1035704  03/09/2020 0001492258                      1200
# 41  81733      1039113  03/11/2020 0001492271                       100
# 42  81733      1043815  03/10/2020 0001492246                       100
# 43  81733      1054901  03/13/2020 0001492273                        15
# 44    NaN          NaN                    NaN                    466026
# 45    NaN          NaN                    NaN                       NaN
# 46    NaN          NaN                    NaN                       NaN
# 47    NaN          NaN            XYZ COMPANY                       NaN
# 48    NaN          NaN      END OF DAY REPORT                       NaN
# 49    NaN          NaN    2020-03-20 00:00:00                       NaN
# 50   PO #  CUSTOMER ID  DATE OF SALERECEIPT #         AMOUNT  SPEEDTYPE
# 51  81736       164304  03/14/2020 0001492293             $50.00 G0400A
# 52  81736       164304  03/14/2020 0001492294             $50.00 G1802A
# 53  81736       820366  03/13/2020 0001492290             $45.00 G0400A
# 54  81736       828968  03/15/2020 0001492291             $50.00 G1385A
# 55  81736       134593  03/16/2020 0001492292            $250.00 G1651A
# 56    NaN          NaN                    NaN                       445
# 57    NaN          NaN                    NaN  GRAND TOTAL: $468,180.78
#
#    SPEED TYPE
# 0         NaN
# 1      G0401A
# 2      G0419A
# 3      G0598A
# 4      G3035A
# 5      G2477A
# 6         NaN
# 7         NaN
# 8         NaN
# 9       A0176
# 10      A0116
# 11      A0168
# 12      A8008
# 13      A0108
# 14      A8008
# 15      A8008
# 16      A8008
# 17      A0168
# 18      A8008
# 19      A8008
# 20      A0108
# 21      A0063
# 22      A8008
# 23      A0168
# 24      A0018
# 25      A8008
# 26      A0168
# 27      A5737
# 28      A8005
# 29      A0168
# 30      A8008
# 31      A0168
# 32      A0010
# 33      A0108
# 34      A0176
# 35      A8008
# 36      A8008
# 37      A8008
# 38      A8008
# 39      A8008
# 40      A8008
# 41      A8008
# 42      A0010
# 43      AWBBL
# 44        NaN
# 45        NaN
# 46        NaN
# 47        NaN
# 48        NaN
# 49        NaN
# 50        NaN
# 51        NaN
# 52        NaN
# 53        NaN
# 54        NaN
# 55        NaN
# 56        NaN
# 57        NaN

# %%
# Forward fill blank POs
main_total['PO #'] = main_total['PO #'].ffill()

# %%
# Filter out NAs
main_total = main_total.loc[~main_total['AMOUNT'].isna()]

# %%
# Fill subtotal NAs
main_total.loc[main_total['CUSTOMER ID'].isna(), ['CUSTOMER ID', 'DATE OF SALERECEIPT #', 'SPEED TYPE']] = 'Subtotal'
# Out:
# C:\Users\jmfon\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\jmfon\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Filter the messy daily totals with the cleaner POs
totals_filter = main_total['PO #'].unique()

# %%
# Use numbers only
totals_filter = [i for i in totals_filter if isinstance(i, int) is True]

# %%
# View the main totals again with the filter
main_total.loc[main_total['PO #'].isin(totals_filter)].style.bar(subset=['AMOUNT', 'AMOUNT.1'], align='mid', color=['#d65f5f', '#5fba7d']).highlight_null(null_color='red')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style.py in _repr_html_(self)
#     180         Hooks into Jupyter notebook rich display system.
#     181         """
# --> 182         return self.render()
#     183
#     184     @Appender(
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style.py in render(self, **kwargs)
#     535         * table_attributes
#     536         """
# --> 537         self._compute()
#     538         # TODO: namespace all the pandas keys
#     539         d = self._translate()
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style.py in _compute(self)
#     610         r = self
#     611         for func, args, kwargs in self._todo:
# --> 612             r = func(self)(*args, **kwargs)
#     613         return r
#     614
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style.py in _apply(self, func, axis, subset, **kwargs)
#     616         subset = slice(None) if subset is None else subset
#     617         subset = _non_reducing_slice(subset)
# --> 618         data = self.data.loc[subset]
#     619         if axis is not None:
#     620             result = data.apply(func, axis=axis, result_type="expand", **kwargs)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1287                 continue
#    1288
# -> 1289             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1290
#    1291         return retval
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1952                     raise ValueError("Cannot index with multidimensional key")
#    1953
# -> 1954                 return self._getitem_iterable(key, axis=axis)
#    1955
#    1956             # nested tuple slicing
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1593         else:
#    1594             # A collection of keys
# -> 1595             keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1596             return self.obj._reindex_with_indexers(
#    1597                 {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1653             if not (ax.is_categorical() or ax.is_interval()):
#    1654                 raise KeyError(
# -> 1655                     "Passing list-likes to .loc or [] with any missing labels "
#    1656                     "is no longer supported, see "
#    1657                     "https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike"  # noqa:E501
#
# KeyError: 'Passing list-likes to .loc or [] with any missing labels is no longer supported, see https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike'

# %%
# View the PO Breakdown
daily_totals.loc[daily_totals['PO #'].isin(totals_filter)].style.bar(subset=['SALE AMT', 'TOTAL '], align='mid', color=['#d65f5f', '#5fba7d']).highlight_null(null_color='red')
# Out:
# <style  type="text/css" >
#     #T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.4%, transparent 0.4%);
#             : ;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col9 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.4%, transparent 0.4%);
#             : ;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col11 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col12 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col14 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col15 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col16 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col17 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col18 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col19 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col20 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col21 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col22 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col23 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col24 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row1_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#             : ;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row1_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#             : ;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row1_col11 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row1_col12 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row1_col13 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row1_col14 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row1_col15 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row1_col16 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row1_col17 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row1_col18 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row1_col19 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row1_col20 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row1_col24 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row2_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.1%, transparent 0.1%);
#             : ;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row2_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.1%, transparent 0.1%);
#             : ;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row2_col11 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row2_col12 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row2_col14 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row2_col15 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row2_col16 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row2_col17 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row2_col18 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row2_col19 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row2_col20 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row2_col21 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row2_col22 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row2_col23 {
#             background-color:  red;
#         }    #T_30f79f9c_8551_11ea_943c_405bd895c2f4row2_col24 {
#             background-color:  red;
#         }</style><table id="T_30f79f9c_8551_11ea_943c_405bd895c2f4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SALES ID</th>        <th class="col_heading level0 col1" >DEPOSIT DATE</th>        <th class="col_heading level0 col2" >TENDER TYPE</th>        <th class="col_heading level0 col3" >SALES TYPE</th>        <th class="col_heading level0 col4" >PO #</th>        <th class="col_heading level0 col5" >DATE OF SALE</th>        <th class="col_heading level0 col6" >TAX RCPT</th>        <th class="col_heading level0 col7" >SPECIAL</th>        <th class="col_heading level0 col8" >SALE AMT</th>        <th class="col_heading level0 col9" >TAX EXEMPT AMT</th>        <th class="col_heading level0 col10" >TOTAL </th>        <th class="col_heading level0 col11" >QUOTE AMT</th>        <th class="col_heading level0 col12" >RESTRICTED USE</th>        <th class="col_heading level0 col13" >CURRENT USE</th>        <th class="col_heading level0 col14" >ATH CU</th>        <th class="col_heading level0 col15" >ATH CAP</th>        <th class="col_heading level0 col16" >ATH AC CU</th>        <th class="col_heading level0 col17" >ATH RESTRICTRED</th>        <th class="col_heading level0 col18" >RESTRICTED PD</th>        <th class="col_heading level0 col19" >CURRENT USE PD</th>        <th class="col_heading level0 col20" >ATH CU PD</th>        <th class="col_heading level0 col21" >ATH CAP PD</th>        <th class="col_heading level0 col22" >ATH CU PD.1</th>        <th class="col_heading level0 col23" >ATH RESTRICTED PD</th>        <th class="col_heading level0 col24" >ADJ</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_30f79f9c_8551_11ea_943c_405bd895c2f4level0_row0" class="row_heading level0 row0" >147</th>
#                         <td id="T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col0" class="data row0 col0" >2</td>
#                         <td id="T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col1" class="data row0 col1" >2020-03-19 00:00:00</td>
#                         <td id="T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col2" class="data row0 col2" >CK</td>
#                         <td id="T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col3" class="data row0 col3" >Check</td>
#                         <td id="T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col4" class="data row0 col4" >81730</td>
#                         <td id="T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col5" class="data row0 col5" >2020-03-20 00:00:00</td>
#                         <td id="T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col6" class="data row0 col6" >5</td>
#                         <td id="T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_30f79f9c_8551_11ea_943c_405bd895c2f4row0_col8" class="data row0 col8" >1710

# %%
# View the other total once more
main_grand_total
# Out:
# 468180.78

# %%
# I think this is what we want
daily_totals.loc[daily_totals['PO #'].isin(totals_filter), 'SALE AMT'].sum()
# Out:
# 468180.78

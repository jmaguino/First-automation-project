# %%
import openpyxl
import os
import pandas as pd
from openpyxl import load_workbook
import numpy

# %%
daily_totals = pd.read_excel ('SALES LOG - XYZ COMPANY.xlsx',nrows=154)
daily_totals
# Out:
#      SALES ID         DEPOSIT DATE TENDER TYPE SALES TYPE   PO # DATE OF SALE  \
# 0         1.0  2020-02-26 00:00:00          CK      Check  81551   2020-03-02
# 1         1.0  2020-02-27 00:00:00          CK      Check  81563   2020-03-02
# 2         1.0  2020-02-27 00:00:00          CK      Check  81564   2020-03-02
# 3         4.0  2020-02-27 00:00:00          CK      Check  81565   2020-03-02
# 4         4.0  2020-02-27 00:00:00          CK      Check  81566   2020-03-02
# ..        ...                  ...         ...        ...    ...          ...
# 149       3.0                  NaN          QU      Quote  81732   2020-03-20
# 150       2.0                  GPD          WR    Wire In  81733   2020-03-20
# 151       3.0                  NaN          CK      Check  81734          NaT
# 152       NaN  2020-03-20 00:00:00          CK      Check  81735          NaT
# 153       2.0  2020-03-20 00:00:00          CK      Check  81736   2020-03-20
#
# ...

# %%
pwd
# Out:
# 'C:\\Users\\jmfon\\Documents\\Automation_Project\\First-automation-project'

# %%
main_total = pd.read_excel ('tabula-END OF DAY REPORT - XYZ COMPANY.xlsx') 
main_total
# Out:
#    Unnamed: 0   Unnamed: 1            XYZ COMPANY                Unnamed: 3  \
# 0         NaN          NaN      End of Day Report                       NaN
# 1         NaN          NaN    2020-03-20 00:00:00                       NaN
# 2        PO #  CUSTOMER ID  DATE OF SALERECEIPT #                    AMOUNT
# 3       81730          NaN                    NaN                       NaN
# 4         NaN       126104  03/13/2020 0001492287                        40
# 5         NaN       139729  03/12/2020 0001492286                        50
# 6         NaN       415802  03/14/2020 0001492281                       100
# 7         NaN      1018908  03/12/2020 0001492288                        20
# 8         NaN      1065569  03/05/2020 0001492289                      1500
# 9         NaN          NaN                    NaN                      1710
# 10      81730          NaN                    NaN                       NaN
# ...
